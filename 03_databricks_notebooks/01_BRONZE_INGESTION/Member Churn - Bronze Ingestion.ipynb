# %%
-- 01_BRONZE_INGESTION.SQL

-- Layer: Bronze (Raw Data)
 Copy raw tables from default into bronze exactly.


-- 1): Create Bronze Schema
CREATE SCHEMA IF NOT EXISTS workspace.bronze;

-- 2): Ingest Raw Tables
CREATE OR REPLACE TABLE workspace.bronze.sqlite_members AS
SELECT • FROM workspace.default.sqlite_members;

CREATE OR REPLACE TABLE workspace.bronze.sqlite_accounts AS
SELECT * FROM workspace.default.sqlite_accounts;

CREATE OR REPLACE TABLE workspace.bronze.sqlite_transactions AS
SELECT • FROM workspace.default.sqlite_transactions;
