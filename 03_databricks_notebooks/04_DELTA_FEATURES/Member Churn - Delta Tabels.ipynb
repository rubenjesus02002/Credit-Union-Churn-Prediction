# %%
-- 04_DELTA_FEATURES.SQL
-- Purpose: Showcase Databricks Delta Table superpowers.
--          ACID transactions, Time Travel, and Optimization.
 
-- Feature 1: DESCRIBE HISTORY (Compliance Audit Trail)
-- See every change ever made to a table — who, when, what.

DESCRIBE HISTORY workspace.gold.churn_by_persona;
 
-- Feature 2: Time Travel
-- Query a table exactly as it looked at a specific version.
SELECT * FROM workspace.gold.churn_by_persona
VERSION AS OF 0;
 
-- Feature 3: OPTIMIZE
-- Clean up file clutter after big data loads.
-- Improves query performance across the Gold layer.
OPTIMIZE workspace.gold.churn_by_persona;
OPTIMIZE workspace.gold.avg_balance_per_status;
OPTIMIZE workspace.gold.transaction_summary;
OPTIMIZE workspace.gold.churn_breakdown;
